# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabilahn/IEF-NABILAH-MOHD-NOOR/blob/main/Source_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing Libraries
import seaborn as sns
# import pandas as pd
import pandas as pd

# importing matplotlib module
import matplotlib.pyplot as plt
plt.style.use('default')

# %matplotlib inline: only draw static
# images in the notebook
# %matplotlib inline

# %%
# importing Data
banjir = pd.read_csv('banjir.csv')
banjir.head(78)
# Out:
#     ID  negeri             tempat tarikhMula tarikhTamat  Tahun
# 0    1  Perlis         sg. Perlis     17-Dec      25-Dec   2005
# 1    2  Perlis           Sg. Arau     17-Dec      24-Dec   2005
# 2    3  Perlis          Sg. Buluh      1-Nov       8-Nov   2010
# 3    4  Perlis  Sg. Alor Mentalun     21-Oct      22-Oct   2010
# 4    5  Perlis           Sg Buluh      1-Nov       8-Nov   2010
# ..  ..     ...                ...        ...         ...    ...
# 73  74   Kedah           sg. baru      7-Nov      10-Nov   2009
# 74  75   Kedah     sg. Pdg. Terap      7-Nov      10-Nov   2009
# 75  76   Kedah           sg. bata      7-Nov      10-Nov   2009
# 76  77   Kedah          sg. Temin      7-Nov      10-Nov   2009
# 77  78   Kedah          sg. Kedah     30-Oct       3-Nov   2010
#
# [78 rows x 6 columns]

# %% [markdown]
# # **Aggrigate Data**

# %% [markdown]
# 1.   Total Floods in  each Year

# %%
Bil_banjir = banjir.groupby(["Tahun"])["Tahun"].count().reset_index(name="Bil Banjir")
Bil_banjir.head(78)
# Out:
#    Tahun  Bil Banjir
# 0   2002           5
# 1   2003          16
# 2   2005          12
# 3   2006          16
# 4   2007          24
# 5   2008          17
# 6   2009          38
# 7   2010          31

# %%
# Save as newsdatastudent1.csv
Bil_banjir.to_csv("Bil_banjir.csv")

# %% [markdown]
# 2.   Total Floods that happen in each State

# %%
total_by_negeri = banjir.groupby("negeri")["tempat"].count().reset_index(name="Bil Kes")
total_by_negeri
# Out:
#    negeri  Bil Kes
# 0   Kedah      137
# 1  Perlis       22

# %% [markdown]
# 3.   Total Floods that happen in each State and year

# %%
Bil_Banjir = banjir.groupby(["tempat","Tahun"])["tempat"].count().reset_index(name="Bil Banjir")
Bil_Banjir.head(78)
# Out:
#             tempat  Tahun  Bil Banjir
# 0         Sg Buluh   2010           1
# 1        Sg Jerneh   2010           1
# 2       Sg Panggas   2010           1
# 3       Sg pelarit   2010           1
# 4          Sg. Abi   2010           1
# ..             ...    ...         ...
# 73  sg. Pdg. Terap   2008           1
# 74  sg. Pdg. Terap   2009           1
# 75  sg. Pdg. Terap   2010           1
# 76  sg. Pdg. terap   2007           1
# 77     sg. Pelarit   2009           1
#
# [78 rows x 3 columns]

# %% [markdown]
# # **Visualize Data**

# %% [markdown]
# 1. Bar Graph to show the Total Floods that happen in each State

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'negeri', y = 'Bil Kes', data=total_by_negeri)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# 2. Bar Graph to show the Total Floods in each Year

# %%
sns.set(style="whitegrid", color_codes=True)
sns.barplot(x = 'Tahun', y = 'Bil Banjir', data=Bil_banjir)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# 3. Total Floods that happen in Malaysia using Line graph

# %%
# code
# importing Data
Bil_banjir = pd.read_csv('Bil_banjir.csv',
					index_col='Tahun',
					parse_dates=True)
Bil_banjir.head(78)
# Out:
#             Unnamed: 0  Bil Banjir
# Tahun
# 2002-01-01           0           5
# 2003-01-01           1          16
# 2005-01-01           2          12
# 2006-01-01           3          16
# 2007-01-01           4          24
# 2008-01-01           5          17
# 2009-01-01           6          38
# 2010-01-01           7          31

# %%
# code
# Visualizing Floods that happen in Malaysia using Line graph

# to set the plot size
plt.figure(figsize=(16, 8), dpi=150)

# using plot method to plot data.
# in plot method we set the label and color of the curve.
Bil_banjir['Bil Banjir'].plot(label='banjir', color='orange')


# adding title to the plot
plt.title('Floods that happen in Malaysia using Line graph')

# adding Label to the x-axis
plt.xlabel('Tahun')

# adding legend to the curve
plt.legend()

# %%
Bil_tempat = banjir.groupby(["tempat","Tahun"])["tempat"].count().reset_index(name="Bil Banjir")
Bil_tempat.head(78)
# Out:
#             tempat  Tahun  Bil Banjir
# 0         Sg Buluh   2010           1
# 1        Sg Jerneh   2010           1
# 2       Sg Panggas   2010           1
# 3       Sg pelarit   2010           1
# 4          Sg. Abi   2010           1
# ..             ...    ...         ...
# 73  sg. Pdg. Terap   2008           1
# 74  sg. Pdg. Terap   2009           1
# 75  sg. Pdg. Terap   2010           1
# 76  sg. Pdg. terap   2007           1
# 77     sg. Pelarit   2009           1
#
# [78 rows x 3 columns]

# %%
# Save as newsdatastudent1.csv
Bil_tempat.to_csv("Bil_tempat.csv")

# %%
# importing Data
df = pd.read_csv('Bil_tempat.csv')
df.head(78)
# Out:
#             tempat  Tahun  Bil Banjir
# 0         Sg Buluh   2010           1
# 1        Sg Jerneh   2010           1
# 2       Sg Panggas   2010           1
# 3       Sg pelarit   2010           1
# 4          Sg. Abi   2010           1
# ..             ...    ...         ...
# 73  sg. Pdg. Terap   2008           1
# 74  sg. Pdg. Terap   2009           1
# 75  sg. Pdg. Terap   2010           1
# 76  sg. Pdg. terap   2007           1
# 77     sg. Pelarit   2009           1
#
# [78 rows x 3 columns]

# %%
lp=sns.lineplot(data=df, x="Tahun", y="Bil Banjir", hue="tempat")
lp.legend(loc='upper right', bbox_to_anchor=(1.5, 1))
